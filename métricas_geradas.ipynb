# %% [markdown]
# <a href="https://colab.research.google.com/github/xdlimao/colab-notebooks/blob/main/m%C3%A9tricas_geradas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 📒 **Cálculo das Métricas**
#
# ---
#
# **Valores Extraídos da Matriz de Confusão:**
# - **VP:** 8.91
# - **FP:** 0.04
# - **FN:** 0.03
# - **VN:** 0.92
# - **N:** 10
#
# ---
#
# **Resultados:**
# - **Sensibilidade:** 0.9966 (99.66%)
# - **Especificidade:** 0.9583 (95.83%)
# - **Acurácia:** 0.983 (98.3%)
# - **Precisão:** 0.9955 (99.55%)
# - **F-score:** 0.996 (99.6%)
